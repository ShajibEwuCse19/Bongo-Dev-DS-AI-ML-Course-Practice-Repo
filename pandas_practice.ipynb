# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.9 MB 9.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.9 MB 6.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.9 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 6.4 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
import numpy as np 
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 2.4.2
# 3.0.1
